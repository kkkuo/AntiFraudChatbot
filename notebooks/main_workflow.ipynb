# %% [markdown]
# <a href="https://colab.research.google.com/github/kkkuo/AntiFraudChatbot/blob/main/main_workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kkkuo/AntiFraudChatbot.git
# Out:
# Cloning into 'AntiFraudChatbot'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 58 (delta 20), reused 35 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 85.29 MiB | 17.27 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# Updating files: 100% (11/11), done.

# %%
# %cd /content/AntiFraudChatbot
# Out:
# /content/AntiFraudChatbot

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 97.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 71.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.7/437.7 kB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...

# %%
#也可以不執行，已經有之前爬好的資料
#重複執行可能會被鎖IP

from scripts.fetch_data import fetch_data
fetch_data(verbose=True)

# %%
from scripts.prepare_dataset import prepare_dataset

prepare_dataset()
# Out:
# ✅ 已儲存 49767 筆資料到 data/fraud_data.csv

# %%
from scripts.embed_and_index import embed_and_save_faiss

embed_and_save_faiss()
# Out:
# Batches:   0%|          | 0/1556 [00:00<?, ?it/s]
# ✅ 已建立並儲存 49767 筆資料的 FAISS index

# %%
from scripts.search_interface import search_similar_cases

search_similar_cases("我上網賣東西，結果有人跟我說我的賣場沒辦法下單，說我提供的賣貨便連結有問題，叫我去找客服")
# Out:
# 相似案例： 我是網路上的平台賣家，那天我在上面賣商品，突然接到一個網友私訊我，說他家人想買，給我連結方便聯繫。
# 我加了之後，對方說要走拍賣平台交易，我也就照做提供連結，但他又說怎樣都無法下單。接著他又傳一個自稱是「客服」，說我沒通過什麼賣家驗證、沒實名制、金流沒開之類的，叫我聯絡另一個帳號，說是「銀行客服」。
# 我一開始還覺得是正規流程，他們甚至還傳我一個「三大保障協議」要我辦理。我就傻傻地配合到最後，結果發現整件事是套好的局，從假買家、假客服到假銀行，全是假的！我被騙得團團轉…
# 詐騙類型： 假買家騙賣家詐騙
# ------------------------------
# 相似案例： 我是個在網路賣東西的賣家，日前下午，一個買家聯絡我，說想買我的商品，但他希望用「超商平台」交易。
# 我按照指示在該平台開了賣場，但對方說「系統顯示無法訂購」，然後丟了一個「客服」的網址給我，叫我去聯繫。
# 我點進去之後，對方自稱客服，說我需要進行「賣家驗證」，接著又有個「銀行專員」打電話來，說要驗證金流，才能開通交易功能。
# 我照著他們的指示，分批轉帳了幾十萬……結果，對方一拿到錢就消失，這時我才驚覺自己被騙了！
# 詐騙類型： 假買家騙賣家詐騙
# ------------------------------
# 相似案例： 我在網路上上開店賣東西，日前有一位買家用通訊軟體聯繫我，說想購買商品，並建議透過超商提供的平台交易。
# 我按照指示，前往該平台創建賣場，並將連結提供給買家。但對方說 無法完成訂購，還傳來一個自稱是「平台客服」 的網址，叫我去聯絡。
# 點進去後，所謂的「客服」告訴我，因為沒有開通金流服務，所以要進行驗證。接著，我接到一通自稱「銀行專員」的電話，對方說要進行「金流驗證」，我才能正常收款。
# 對方一再強調「這是必要程序」，我於是照做，陸續轉帳幾萬元。但當我開始懷疑、拒絕再配合時，對方立刻失聯，這才發現自己 被詐騙了！
# 詐騙類型： 假買家騙賣家詐騙
# ------------------------------

# %%
from scripts.qa_interface import run_qa

run_qa("有人傳簡訊說我是金融詐騙，要我交出金融卡")
# Out:
# tokenizer_config.json:   0%|          | 0.00/766 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/844k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/10.2G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.69G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/131 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0
# ...
